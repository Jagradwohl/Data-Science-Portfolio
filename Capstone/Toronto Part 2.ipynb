# %%
#begin by importing your lbiraries 
import pandas as pd
import numpy as np 
import csv
import requests
from bs4 import BeautifulSoup  #Beautifulsoup is used to separate out the HTML
get_ipython().system('conda install beautifulsoup4')
# Out:
# Solving environment: done
#
# # All requested packages already installed.

# %%
pd.set_option('max_colwidth', 800)

# %% [markdown]
# # Preprocessing and table extraction from Wikipedia

# %%
#This is a request to pull the wikipedia page in. 
Page = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

# %%
# getting data from internet
wikipedia_link='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
raw_wikipedia_page= requests.get(wikipedia_link).text
#using the soup library
soup = BeautifulSoup(raw_wikipedia_page,'xml')

# %%
# Creating our Table
table = soup.find('table')

Postcode      = []
Borough       = []
Neighbourhood = []



#Make sure our table is clean when we pull it from wikipedia
for tr_cell in table.find_all('tr'):
    
    counter = 1
    Postcode_var      = -1
    Borough_var       = -1
    Neighbourhood_var = -1
    
    for td_cell in tr_cell.find_all('td'):
        if counter == 1: 
            Postcode_var = td_cell.text
        if counter == 2: 
            Borough_var = td_cell.text
            tag_a_Borough = td_cell.find('a')
            
        if counter == 3: 
            Neighbourhood_var = str(td_cell.text).strip()
            tag_a_Neighbourhood = td_cell.find('a')
            
        counter +=1
        
    if (Postcode_var == 'Not assigned' or Borough_var == 'Not assigned' or Neighbourhood_var == 'Not assigned'): 
        continue
    try:
        if ((tag_a_Borough is None) or (tag_a_Neighbourhood is None)):
            continue
    except:
        pass
    if(Postcode_var == -1 or Borough_var == -1 or Neighbourhood_var == -1):
        continue
        
Postcode.append(Postcode_var)
Borough.append(Borough_var)
Neighbourhood.append(Neighbourhood_var)

# %%
#Organizing multiple neighborhood postal codes 
unique_p = set(Postcode)
print('num of unique Postal codes:', len(unique_p))
Postcode_u      = []
Borough_u       = []
Neighbourhood_u = []


for postcode_unique_element in unique_p:
    p_var = ''; b_var = ''; n_var = ''; 
    for postcode_idx, postcode_element in enumerate(Postcode):
        if postcode_unique_element == postcode_element:
            p_var = postcode_element;
            b_var = Borough[postcode_idx]
            if n_var == '': 
                n_var = Neighbourhood[postcode_idx]
            else:
                n_var = n_var + ', ' + Neighbourhood[postcode_idx]
    Postcode_u.append(p_var)
    Borough_u.append(b_var)
    Neighbourhood_u.append(n_var)
# Out:
# num of unique Postal codes: 77

# %% [markdown]
# # Identifying unique postal codes from the table

# %%
toronto_dict = {'Postcode':Postcode_u, 'Borough':Borough_u, 'Neighbourhood':Neighbourhood_u}
df_toronto = pd.DataFrame.from_dict(toronto_dict)
df_toronto.to_csv('toronto_part1.csv')
df_toronto.head()
# Out:
#   Postcode           Borough                             Neighbourhood
# 0      M9M        North York                          Emery, Humberlea
# 1      M1S       Scarborough                                 Agincourt
# 2      M3H        North York            Bathurst Manor, Wilson Heights
# 3      M3J        North York           Northwood Park, York University
# 4      M5K  Downtown Toronto  Design Exchange, Toronto Dominion Centre

# %%
df_toronto.shape
# Out:
# (77, 3)

# %% [markdown]
# # Part Two: Bringing in the lat, long

# %%
#Install folium and import library for our next section
# !pip install folium

# %%
import folium
import json, lxml
from geopy.geocoders import Nominatim
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans

# %%
df = pd.read_csv (r'http://cocl.us/Geospatial_data')
df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
#We rename the column name for toronto to match the other table
df_toronto.rename(columns = {"Postcode": "Postal Code"}, inplace=True)
df_toronto.head()
# Out:
#   Postal Code           Borough                             Neighbourhood
# 0         M9M        North York                          Emery, Humberlea
# 1         M1S       Scarborough                                 Agincourt
# 2         M3H        North York            Bathurst Manor, Wilson Heights
# 3         M3J        North York           Northwood Park, York University
# 4         M5K  Downtown Toronto  Design Exchange, Toronto Dominion Centre

# %%
#Merge the tables on postal code and create a new dataframe 
canada_df = pd.merge(df_toronto, df, on = "Postal Code")
canada_df
# Out:
#    Postal Code           Borough  \
# 0          M9M        North York
# 1          M1S       Scarborough
# 2          M3H        North York
# 3          M3J        North York
# 4          M5K  Downtown Toronto
# 5          M1P       Scarborough
# 6          M6K      West Toronto
# 7          M4G         East York
# 8          M1M       Scarborough
# 9          M5V  Downtown Toronto
# 10         M1N       Scarborough
# 11         M4X  Downtown Toronto
# 12         M2J        North York
# 13         M5M        North York
# 14         M4A        North York
# 15         M4C         East York
# 16         M1J       Scarborough
# 17         M4E      East Toronto
# 18         M8X         Etobicoke
# 19         M9B         Etobicoke
# 20         M1R       Scarborough
# 21         M6S      West Toronto
# 22         M2K        North York
# 23         M9C         Etobicoke
# 24         M4H         East York
# 25         M4J         East York
# 26         M3L        North York
# 27         M2M        North York
# 28         M6R      West Toronto
# 29         M4T   Central Toronto
# ..         ...               ...
# 47         M4W  Downtown Toronto
# 48         M4V   Central Toronto
# 49         M6J      West Toronto
# 50         M7A  Downtown Toronto
# 51         M1X       Scarborough
# 52         M9L        North York
# 53         M1E       Scarborough
# 54         M9R         Etobicoke
# 55         M6M              York
# 56         M5C  Downtown Toronto
# 57         M1C       Scarborough
# 58         M6A        North York
# 59         M2H        North York
# 60         M5L  Downtown Toronto
# 61         M8W         Etobicoke
# 62         M1V       Scarborough
# 63         M5E  Downtown Toronto
# 64         M1B       Scarborough
# 65         M4N   Central Toronto
# 66         M6H      West Toronto
# 67         M4Y  Downtown Toronto
# 68         M5P   Central Toronto
# 69         M1L       Scarborough
# 70         M3A        North York
# 71         M2L        North York
# 72         M5S  Downtown Toronto
# 73         M1T       Scarborough
# 74         M8V         Etobicoke
# 75         M2R        North York
# 76         M8Z         Etobicoke
#
#                                                Neighbourhood   Latitude  \
# 0                                           Emery, Humberlea  43.724766
# 1                                                  Agincourt  43.794200
# 2                             Bathurst Manor, Wilson Heights  43.754328
# 3                            Northwood Park, York University  43.767980
# 4                   Design Exchange, Toronto Dominion Centre  43.647177
# 5      Dorset Park, Scarborough Town Centre, Wexford Heights  43.757410
# 6                         Exhibition Place, Parkdale Village  43.636847
# 7                                                    Leaside  43.709060
# 8                                      Cliffcrest, Cliffside  43.716316
# 9   CN Tower, King and Spadina, Railway Lands, South Niagara  43.628947
# 10                                               Birch Cliff  43.692657
# 11                               Cabbagetown, St. James Town  43.667967
# 12                                                Henry Farm  43.778517
# 13                                              Bedford Park  43.733283
# 14                                          Victoria Village  43.725882
# 15                                          Woodbine Heights  43.695344
# 16                                       Scarborough Village  43.744734
# 17                                               The Beaches  43.676357
# 18                                              The Kingsway  43.653654
# 19              Islington, Princess Gardens, West Deane Park  43.650943
# 20                                         Maryvale, Wexford  43.750072
# 21                                        Runnymede, Swansea  43.651571
# 22                                           Bayview Village  43.786947
# 23                                             Markland Wood  43.643515
# 24                                          Thorncliffe Park  43.705369
# 25                                              East Toronto  43.685347
# 26                                            Downsview West  43.739015
# 27                                   Newtonbrook, Willowdale  43.789053
# 28                                    Parkdale, Roncesvalles  43.648960
# 29                                                Moore Park  43.689574
# ..                                                       ...        ...
# 47                                                  Rosedale  43.679563
# 48                          Deer Park, Rathnelly, South Hill  43.686412
# 49                                  Little Portugal, Trinity  43.647927
# 50                                              Queen's Park  43.662301
# 51                                               Upper Rouge  43.836125
# 52                                             Humber Summit  43.756303
# 53                                    Morningside, West Hill  43.763573
# 54                                         Kingsview Village  43.688905
# 55                     Keelesdale, Mount Dennis, Silverthorn  43.691116
# 56                                            St. James Town  43.651494
# 57                    Highland Creek, Rouge Hill, Port Union  43.784535
# 58                          Lawrence Heights, Lawrence Manor  43.718518
# 59                                         Hillcrest Village  43.803762
# 60                                            Commerce Court  43.648198
# 61                                    Alderwood, Long Branch  43.602414
# 62                                 Agincourt North, Milliken  43.815252
# 63                                               Berczy Park  43.644771
# 64                                            Rouge, Malvern  43.806686
# 65                                             Lawrence Park  43.728020
# 66                                        Dovercourt Village  43.669005
# 67                                      Church and Wellesley  43.665860
# 68                                         Forest Hill North  43.696948
# 69                           Clairlea, Golden Mile, Oakridge  43.711112
# 70                                                 Parkwoods  43.753259
# 71                                                York Mills  43.757490
# 72                                     University of Toronto  43.662696
# 73                                             Tam O'Shanter  43.781638
# 74                                               New Toronto  43.605647
# 75                                           Willowdale West  43.782736
# 76                             Mimico NW, The Queensway West  43.628841
#
#     Longitude
# 0  -79.532242
# 1  -79.262029
# 2  -79.442259
# 3  -79.487262
# 4  -79.381576
# 5  -79.273304
# 6  -79.428191
# 7  -79.363452
# 8  -79.239476
# 9  -79.394420
# 10 -79.264848
# 11 -79.367675
# 12 -79.346556
# 13 -79.419750
# 14 -79.315572
# 15 -79.318389
# 16 -79.239476
# 17 -79.293031
# 18 -79.506944
# 19 -79.554724
# 20 -79.295849
# 21 -79.484450
# 22 -79.385975
# 23 -79.577201
# 24 -79.349372
# 25 -79.338106
# 26 -79.506944
# 27 -79.408493
# 28 -79.456325
# 29 -79.383160
# ..        ...
# 47 -79.377529
# 48 -79.400049
# 49 -79.419750
# 50 -79.389494
# 51 -79.205636
# 52 -79.565963
# 53 -79.188711
# 54 -79.554724
# 55 -79.476013
# 56 -79.375418
# 57 -79.160497
# 58 -79.464763
# 59 -79.363452
# 60 -79.379817
# 61 -79.543484
# 62 -79.284577
# 63 -79.373306
# 64 -79.194353
# 65 -79.388790
# 66 -79.442259
# 67 -79.383160
# 68 -79.411307
# 69 -79.284577
# 70 -79.329656
# 71 -79.374714
# 72 -79.400049
# 73 -79.304302
# 74 -79.501321
# 75 -79.442259
# 76 -79.520999
#
# [77 rows x 5 columns]
